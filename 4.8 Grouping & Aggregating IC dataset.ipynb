# %% [markdown]
# # Importing libraries

# %%
# Importing needed libraries
import pandas as pd
import numpy as np
import os

# %%
# Turning project folder into string path 
path = r'C:\Users\keirr\11-2020 Instacart Basket Analysis'

# %%
# Importing orders_products_combined.pkl dataset with path
ords_prods_new = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_new_cols.pkl'))

# %%
# Checking imported df
ords_prods_new.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#   busiest_days  slowest_days busiest_period_of_day
# 0          NaN           NaN        Regularly busy
# 1          NaN  Slowest days        Regularly busy
# 2          NaN  Slowest days        Regularly busy
# 3          NaN  Slowest days            Least busy
# 4          NaN  Slowest days            Least busy

# %% [markdown]
# # Contents
# ## 1. Grouping & aggregrating df
# ## 2. Creating 'loyalty_flag' column
# ## 3. Checking basic stats of loyalty flags
# ## 4. Creating 'spending_flag' column
# ## 5. Creating 'frequency_flag' column
# ## 6. Exporting df

# %% [markdown]
# # 1. Grouping & aggregrating df

# %%
# Grouping data by 'department_id', and finding mean of 'order_num'
ords_prods_new.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Insights: without subsetting the df to include the first 1 million entries, I can see that certain departments were excluded from the data, as well as slightly changing the mean of most 'department_id'

# %%
# Grouping data by 'department_id', additionally looking into min and max
ords_prods_new.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# # 2. Creating loyalty flag

# %% [markdown]
# ## Using transform() function to create 'max_order'

# %%
# Splitting the data into groups based on the “user_id” column
# Applying the transform() function on the 'order_number' column to generate the max orders for each user
# Creating a new column, 'max_order' for results of agg()

ords_prods_new['max_order'] = ords_prods_new.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\keirr\AppData\Local\Temp\ipykernel_28816\3825906525.py:5: FutureWarning: The provided callable <function amax at 0x000002332A9B1BC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_new['max_order'] = ords_prods_new.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking df
ords_prods_new.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#   busiest_days  slowest_days busiest_period_of_day  max_order
# 0          NaN           NaN        Regularly busy         10
# 1          NaN  Slowest days        Regularly busy         10
# 2          NaN  Slowest days        Regularly busy         10
# 3          NaN  Slowest days            Least busy         10
# 4          NaN  Slowest days            Least busy         10

# %% [markdown]
# ## Deriving new column with loc() function

# %%
ords_prods_new.loc[ords_prods_new['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\keirr\AppData\Local\Temp\ipykernel_28816\2903401466.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_new.loc[ords_prods_new['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_new.loc[(ords_prods_new['max_order'] <= 40) & (ords_prods_new['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_new.loc[ords_prods_new['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking work
ords_prods_new[['user_id', 'loyalty_flag', 'order_number']].head(15)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22

# %% [markdown]
# # 3. Checking basic stats of loyalty flags

# %%
# Grouping data by 'loyalty flag' & agg 'prices' col

ords_prods_new.groupby('loyalty_flag').agg({'prices':['mean', 'max', 'min']})
# Out:
#                      prices
#                        mean      max  min
# loyalty_flag
# Loyal customer    10.386336  99999.0  1.0
# New customer      13.294670  99999.0  1.0
# Regular customer  12.495717  99999.0  1.0

# %% [markdown]
# ### Insights: 'new customers' have the highest average price per product bought, followed by 'regular customers' and then 'loyal customers'. Perhaps 'new customers' are making infrequent large purchases, whereas 'regular' and 'loyal customers' are making frequent smaller purchases in comparison.

# %% [markdown]
# # 4. Creating 'spending_flag' column

# %% [markdown]
# ## Creating 'mean_price' col w/ transform()

# %%
# Splitting the data into groups based on the “user_id” column
# Applying the transform() function on the 'prices' column to generate average price of product for each user
# Creating a new column, 'mean_price' for results of agg()

ords_prods_new['mean_price'] = ords_prods_new.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\keirr\AppData\Local\Temp\ipykernel_28816\2489093551.py:5: FutureWarning: The provided callable <function mean at 0x000002332A9B28E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_new['mean_price'] = ords_prods_new.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Checking df
ords_prods_new.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge    price_range_loc  \
# 0         Soda  ...              7     9.0    both  Mid-range product
# 1         Soda  ...              7     9.0    both  Mid-range product
# 2         Soda  ...              7     9.0    both  Mid-range product
# 3         Soda  ...              7     9.0    both  Mid-range product
# 4         Soda  ...              7     9.0    both  Mid-range product
#
#   busiest_days  slowest_days busiest_period_of_day max_order  loyalty_flag  \
# 0          NaN           NaN        Regularly busy        10  New customer
# 1          NaN  Slowest days        Regularly busy        10  New customer
# 2          NaN  Slowest days        Regularly busy        10  New customer
# 3          NaN  Slowest days            Least busy        10  New customer
# 4          NaN  Slowest days            Least busy        10  New customer
#
#   mean_price
# 0   6.367797
# 1   6.367797
# 2   6.367797
# 3   6.367797
# 4   6.367797
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Deriving new variable w/ loc() function

# %%
ords_prods_new.loc[ords_prods_new['mean_price'] < 10, 'spending_flag'] = 'Low spender'
# Out:
# C:\Users\keirr\AppData\Local\Temp\ipykernel_28816\956784933.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_new.loc[ords_prods_new['mean_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_new.loc[ords_prods_new['mean_price'] >= 10, 'spending_flag'] = "High spender"

# %%
# Checking df
ords_prods_new.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  prices  _merge    price_range_loc busiest_days  \
# 0         Soda  ...     9.0    both  Mid-range product          NaN
# 1         Soda  ...     9.0    both  Mid-range product          NaN
# 2         Soda  ...     9.0    both  Mid-range product          NaN
# 3         Soda  ...     9.0    both  Mid-range product          NaN
# 4         Soda  ...     9.0    both  Mid-range product          NaN
#
#    slowest_days busiest_period_of_day max_order  loyalty_flag  mean_price  \
# 0           NaN        Regularly busy        10  New customer    6.367797
# 1  Slowest days        Regularly busy        10  New customer    6.367797
# 2  Slowest days        Regularly busy        10  New customer    6.367797
# 3  Slowest days            Least busy        10  New customer    6.367797
# 4  Slowest days            Least busy        10  New customer    6.367797
#
#   spending_flag
# 0   Low spender
# 1   Low spender
# 2   Low spender
# 3   Low spender
# 4   Low spender
#
# [5 rows x 22 columns]

# %% [markdown]
# # 5. Creating 'frequency_flag' column

# %% [markdown]
# ## Creating 'median_last_order' column w/ transform()

# %%
# Splitting the data into groups based on the 'user_id' column
# Applying the transform() function on the 'days_since_last_order' column to generate frequency of user's shopping
# Creating a new column, 'median_last_order' for results of agg()

ords_prods_new['median_last_order'] = ords_prods_new.groupby(['user_id'])['days_since_last_order'].transform(np.median)
# Out:
# C:\Users\keirr\AppData\Local\Temp\ipykernel_28816\937066586.py:5: FutureWarning: The provided callable <function median at 0x000002332AAF3880> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_new['median_last_order'] = ords_prods_new.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
# Checking df
ords_prods_new.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  _merge    price_range_loc  busiest_days  slowest_days  \
# 0         Soda  ...    both  Mid-range product           NaN           NaN
# 1         Soda  ...    both  Mid-range product           NaN  Slowest days
# 2         Soda  ...    both  Mid-range product           NaN  Slowest days
# 3         Soda  ...    both  Mid-range product           NaN  Slowest days
# 4         Soda  ...    both  Mid-range product           NaN  Slowest days
#
#   busiest_period_of_day max_order  loyalty_flag mean_price  spending_flag  \
# 0        Regularly busy        10  New customer   6.367797    Low spender
# 1        Regularly busy        10  New customer   6.367797    Low spender
# 2        Regularly busy        10  New customer   6.367797    Low spender
# 3            Least busy        10  New customer   6.367797    Low spender
# 4            Least busy        10  New customer   6.367797    Low spender
#
#   median_last_order
# 0              20.5
# 1              20.5
# 2              20.5
# 3              20.5
# 4              20.5
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Deriving new variable w/ loc() function

# %%
ords_prods_new.loc[ords_prods_new['median_last_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\keirr\AppData\Local\Temp\ipykernel_28816\3566390129.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_new.loc[ords_prods_new['median_last_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_new.loc[(ords_prods_new['median_last_order'] > 10) & (ords_prods_new['median_last_order'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_new.loc[ords_prods_new['median_last_order'] <= 10, 'frequency_flag'] = 'Frequenct customer'

# %%
# Checking df
ords_prods_new.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...    price_range_loc  busiest_days  slowest_days  \
# 0         Soda  ...  Mid-range product           NaN           NaN
# 1         Soda  ...  Mid-range product           NaN  Slowest days
# 2         Soda  ...  Mid-range product           NaN  Slowest days
# 3         Soda  ...  Mid-range product           NaN  Slowest days
# 4         Soda  ...  Mid-range product           NaN  Slowest days
#
#   busiest_period_of_day max_order  loyalty_flag mean_price spending_flag  \
# 0        Regularly busy        10  New customer   6.367797   Low spender
# 1        Regularly busy        10  New customer   6.367797   Low spender
# 2        Regularly busy        10  New customer   6.367797   Low spender
# 3            Least busy        10  New customer   6.367797   Low spender
# 4            Least busy        10  New customer   6.367797   Low spender
#
#    median_last_order         frequency_flag
# 0               20.5  Non-frequent customer
# 1               20.5  Non-frequent customer
# 2               20.5  Non-frequent customer
# 3               20.5  Non-frequent customer
# 4               20.5  Non-frequent customer
#
# [5 rows x 24 columns]

# %% [markdown]
# # 6. Exporting df

# %%
# Exporting grouped and aggregated data to pkl

ords_prods_new.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_agg.pkl'))
